# %%
#from collections import defaultdict

#times = defaultdict(list)

with open('BCast', 'r') as f:
    times = list(map(lambda x: float(x)*1.0e9, f.readlines()))

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 16, 9

fig, ax = plt.subplots()
# plot the cumulative histogram
n, bins, patches = plt.hist(times, 1000, normed=1, facecolor='green', alpha=0.75)
plt.xlim(0, 3000)
# Out:
# (0, 3000)

# %%
0.00000119209289550781 - 0.00000095367431640625
# Out:
# 2.3841857910155996e-07

# %%
import numpy as np
t = np.array(times)
np.sort(np.unique(t)*1e9)
# Out:
# array([0.00000000e+00, 9.53674316e+11, 1.19209290e+12, 1.90734863e+12,
#        2.14576721e+12, 2.86102295e+12, 3.09944153e+12, 3.81469727e+12,
#        4.05311584e+12, 8.10623169e+12, 9.05990601e+12, 1.00135803e+13,
#        1.09672546e+13, 1.12056732e+13, 1.19209290e+13, 1.40666962e+13,
#        1.59740448e+13, 1.78813934e+13, 2.09808350e+13, 3.91006470e+13,
#        5.00679016e+13])

# %%
2.14576721e12 - 1.90734863e12
# Out:
# 238418580000.0
